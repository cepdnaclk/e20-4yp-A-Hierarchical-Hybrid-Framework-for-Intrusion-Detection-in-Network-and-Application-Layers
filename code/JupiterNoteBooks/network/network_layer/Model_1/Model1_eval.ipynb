# %%
# ============================================
# import libraries
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, ConfusionMatrixDisplay
import joblib

# %%
# ----------------------------
# Load dataset
# ----------------------------
DATA_PATH = "/home/fyp_ids_e20/processed_dataset/balanced_network_data.csv"
df = pd.read_csv(DATA_PATH)

print("Loaded shape:", df.shape)
print(df["Label"].value_counts().head(20))
# Out:
# Loaded shape: (6870587, 23)
# Label
# Benign                      4122352
# DDOS attack-HOIC             686012
# DDoS attacks-LOIC-HTTP       576191
# DoS attacks-Hulk             461912
# Bot                          286191
# FTP-BruteForce               193360
# SSH-Bruteforce               187589
# Infilteration                161934
# DoS attacks-SlowHTTPTest     139890
# DoS attacks-GoldenEye         41508
# DoS attacks-Slowloris         10990
# DDOS attack-LOIC-UDP           1730
# Brute Force -Web                611
# Brute Force -XSS                230
# SQL Injection                    87
# Name: count, dtype: int64

# %%
# ----------------------------
# Feature list
# ----------------------------
network_features = [
    "Dst Port",
    "Protocol",
    "Flow Duration",
    "Flow IAT Mean",
    "Flow IAT Max",
    "Flow IAT Min",
    "Fwd IAT Max",
    "Fwd IAT Min",
    "Fwd IAT Tot",
    "Flow Pkts/s",
    "Fwd Pkts/s",
    "Bwd Pkts/s",
    "Tot Fwd Pkts",
    "Subflow Fwd Pkts",
    "Fwd Header Len",
    "Bwd Header Len",
    "Init Fwd Win Byts",
    "Init Bwd Win Byts",
    "PSH Flag Cnt",
    "RST Flag Cnt",
    "ACK Flag Cnt",
    "ECE Flag Cnt"
]

missing = [c for c in network_features if c not in df.columns]
if missing:
    print("Missing features skipped:", missing)

network_features = [c for c in network_features if c in df.columns]
print("Using", len(network_features), "features.")
# Out:
# Using 22 features.

# %%
# ----------------------------
# Clean data
# ----------------------------
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(subset=["Label"]).copy()

X = df[network_features].copy()
y = df["Label"].astype(str).copy()

for col in X.columns:
    X[col] = pd.to_numeric(X[col], errors="coerce")

mask = X.notna().all(axis=1)
X = X[mask]
y = y[mask]

# Binary label
# 0 = Benign
# 1 = Attack
y_binary = (y != "Benign").astype(int)

print("Cleaned X shape:", X.shape)
print("Label counts:")
print(y_binary.value_counts())
# Out:
# Cleaned X shape: (6838750, 22)
# Label counts:
# Label
# 0    4091816
# 1    2746934
# Name: count, dtype: int64

# %%
# ----------------------------
# Train / Test split
# ----------------------------
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X,
    y_binary,
    test_size=0.2,
    random_state=42,
    stratify=y_binary
)

print("Train shape:", X_train_raw.shape)
print("Test shape:", X_test_raw.shape)
# Out:
# Train shape: (5471000, 22)
# Test shape: (1367750, 22)

# %%
# ----------------------------
# Scaled version
# Needed for LR, KNN, SVM, MLP
# ----------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_raw)
X_test_scaled = scaler.transform(X_test_raw)

print("Preprocessing complete.")
# Out:
# Preprocessing complete.

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test, model_name="Model"):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    joblib.dump(model, f"{model_name.lower().replace(' ', '_')}_model.joblib")

    print(f"\n===== {model_name} =====")
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    print("Confusion Matrix [[TN, FP], [FN, TP]]:")
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Benign", "Attack"])
    disp.plot(cmap="Blues")
    plt.show()

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=["Benign", "Attack"]))

    # ROC-AUC
    try:
        if hasattr(model, "predict_proba"):
            y_scores = model.predict_proba(X_test)[:, 1]
        elif hasattr(model, "decision_function"):
            y_scores = model.decision_function(X_test)
        else:
            y_scores = None

        if y_scores is not None:
            auc = roc_auc_score(y_test, y_scores)
            print("ROC-AUC:", auc)
    except Exception as e:
        print("ROC-AUC could not be computed:", e)

    return model

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(
    max_iter=1000,
    random_state=42,
    class_weight="balanced",
    n_jobs=-1
)

evaluate_model(
    lr_model,
    X_train_scaled,
    X_test_scaled,
    y_train,
    y_test,
    model_name="Logistic Regression"
)
# Out:
# ===== Logistic Regression =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.85      0.90    818363
#       Attack       0.81      0.94      0.87    549387
#
#     accuracy                           0.89   1367750
#    macro avg       0.88      0.90      0.89   1367750
# weighted avg       0.90      0.89      0.89   1367750
#
# ROC-AUC: 0.9227926569750874
# LogisticRegression(class_weight='balanced', max_iter=1000, n_jobs=-1,
#                    random_state=42)

# %% [markdown]
# ### DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(
    max_depth=None,
    min_samples_split=2,
    random_state=42,
    class_weight="balanced"
)

evaluate_model(
    dt_model,
    X_train_raw,
    X_test_raw,
    y_train,
    y_test,
    model_name="Decision Tree"
)
# Out:
# ===== Decision Tree =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.97      0.97      0.97    818363
#       Attack       0.96      0.95      0.96    549387
#
#     accuracy                           0.97   1367750
#    macro avg       0.96      0.96      0.96   1367750
# weighted avg       0.97      0.97      0.97   1367750
#
# ROC-AUC: 0.9701343356505274
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
import numpy as np

MAX_TRAIN_SVM = 100000

if len(X_train_scaled) > MAX_TRAIN_SVM:
    rng = np.random.RandomState(42)
    idx = rng.choice(len(X_train_scaled), size=MAX_TRAIN_SVM, replace=False)
    X_train_svm = X_train_scaled[idx]
    y_train_svm = y_train.iloc[idx]
else:
    X_train_svm = X_train_scaled
    y_train_svm = y_train

svm_model = SVC(
    kernel="rbf",
    C=1.0,
    gamma="scale",
    probability=True,
    class_weight="balanced",
    random_state=42
)

evaluate_model(
    svm_model,
    X_train_svm,
    X_test_scaled,
    y_train_svm,
    y_test,
    model_name="SVM (RBF)"
)
# Out:
# ===== SVM (RBF) =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.91      0.94    818363
#       Attack       0.88      0.94      0.91    549387
#
#     accuracy                           0.92   1367750
#    macro avg       0.92      0.93      0.92   1367750
# weighted avg       0.93      0.92      0.92   1367750
#
# ROC-AUC: 0.9626837253340434
# SVC(class_weight='balanced', probability=True, random_state=42)

# %% [markdown]
# ### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

evaluate_model(
    gb_model,
    X_train_raw,
    X_test_raw,
    y_train,
    y_test,
    model_name="Gradient Boosting"
)
# Out:
# ===== Gradient Boosting =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.99      0.98    818363
#       Attack       0.99      0.94      0.97    549387
#
#     accuracy                           0.97   1367750
#    macro avg       0.98      0.97      0.97   1367750
# weighted avg       0.97      0.97      0.97   1367750
#
# ROC-AUC: 0.9809261543649161
# GradientBoostingClassifier(random_state=42)

# %% [markdown]
# ### AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_model = AdaBoostClassifier(
    n_estimators=100,
    learning_rate=1.0,
    random_state=42
)

evaluate_model(
    ada_model,
    X_train_raw,
    X_test_raw,
    y_train,
    y_test,
    model_name="AdaBoost"
)
# Out:
# ===== AdaBoost =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.98      0.97    818363
#       Attack       0.97      0.94      0.95    549387
#
#     accuracy                           0.96   1367750
#    macro avg       0.97      0.96      0.96   1367750
# weighted avg       0.96      0.96      0.96   1367750
#
# ROC-AUC: 0.9759864978791186
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %% [markdown]
# ### MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    solver="adam",
    batch_size=256,
    max_iter=50,
    random_state=42,
    early_stopping=True
)

evaluate_model(
    mlp_model,
    X_train_scaled,
    X_test_scaled,
    y_train,
    y_test,
    model_name="MLP Classifier"
)
# Out:
# ===== MLP Classifier =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      1.00      0.98    818363
#       Attack       1.00      0.94      0.97    549387
#
#     accuracy                           0.98   1367750
#    macro avg       0.98      0.97      0.97   1367750
# weighted avg       0.98      0.98      0.98   1367750
#
# ROC-AUC: 0.9851858477327002
# MLPClassifier(batch_size=256, early_stopping=True, hidden_layer_sizes=(128, 64),
#               max_iter=50, random_state=42)

# %% [markdown]
# ### XGBClassifier

# %%
# %pip install xgboost
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss",
    random_state=42,
    n_jobs=-1
)

evaluate_model(
    xgb_model,
    X_train_raw,
    X_test_raw,
    y_train,
    y_test,
    model_name="XGBoost"
)
# Out:
# Requirement already satisfied: xgboost in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: numpy in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (from xgboost) (2.4.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (from xgboost) (2.29.7)
# Requirement already satisfied: scipy in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (from xgboost) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.
#
# ===== XGBoost =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      1.00      0.98    818363
#       Attack       1.00      0.94      0.97    549387
#
#     accuracy                           0.98   1367750
#    macro avg       0.98      0.97      0.98   1367750
# weighted avg       0.98      0.98      0.98   1367750
#
# ROC-AUC: 0.989956019577541
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### LGBMClassifier

# %%
# %pip install lightgbm
from lightgbm import LGBMClassifier

lgbm_model = LGBMClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=-1,
    random_state=42,
    n_jobs=-1
)

evaluate_model(
    lgbm_model,
    X_train_raw,
    X_test_raw,
    y_train,
    y_test,
    model_name="LightGBM"
)
# Out:
# Requirement already satisfied: lightgbm in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (from lightgbm) (2.4.2)
# Requirement already satisfied: scipy in /home/fyp_ids_e20/venv/lib/python3.12/site-packages (from lightgbm) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 2197547, number of negative: 3273453
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.108529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4275
# [LightGBM] [Info] Number of data points in the train set: 5471000, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.401672 -> initscore=-0.398504
# [LightGBM] [Info] Start training from score -0.398504
#
# ===== LightGBM =====
# Confusion Matrix [[TN, FP], [FN, TP]]:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.96      1.00      0.98    818363
#       Attack       1.00      0.94      0.97    549387
#
#     accuracy                           0.98   1367750
#    macro avg       0.98      0.97      0.98   1367750
# weighted avg       0.98      0.98      0.98   1367750
#
# ROC-AUC: 0.9904783305773786
# LGBMClassifier(n_estimators=200, n_jobs=-1, random_state=42)
